# %% [markdown]
# # The German Traffic Sign Benchmark
#
# __Student Name 1:__ Daniel Mínguez Camacho
# __Student Name 2:__ Javier de la Rúa Martínez

# %% [markdown]
# ### Install required packages and dependencies

# %% [markdown]
# Bash: unzip
# Python: numpy, cv2

# %%
# %%bash
#
# bash_packages="unzip"
# python_packages="numpy matplotlib keras tensorflow"
#
# # Bash packages
# for p in $bash_packages; do
#     dpkg -s $p &> /dev/null
#     if [ $? -ne 0 ]; then echo "installing"; sudo apt install -y unzip; fi
# done
#
# # Python packages
# for p in $python_packages; do
#     python -c "import $p" &> /dev/null
#     if [ $? -ne 0 ]; then pip3 install $p; fi
# done
#
# # - opencv-python
# python -c "import cv2" &> /dev/null
# if [ $? -ne 0 ]; then pip3 install opencv-python; sudo apt-get install -y libfontconfig1 libxrender1; fi
#
# # scikit-learn
# python -c "import sklearn" &> /dev/null
# if [ $? -ne 0 ]; then pip3 install scikit-learn; fi

# %% [markdown]
# ### Data preparation

# %% [markdown]
# Download full data set from http://benchmark.ini.rub.de/?section=gtsdb&subsection=dataset

# %%
# Get data
# !if [ ! -f FullIJCNN2013.zip ]; then wget -c http://benchmark.ini.rub.de/Dataset_GTSDB/FullIJCNN2013.zip; else echo "Already downloaded"; fi
    
# Unzip file
# !if [ ! -d FullIJCNN2013 ]; then unzip FullIJCNN2013.zip; else echo "Already unzipped"; fi
# Out:
# Already downloaded
# Already unzipped

# %%
import numpy as np
import cv2

IMG_HEIGHT = 600
SIGN_SIZE = (224, 224)

# Function for reading the images
def readImages(rootpath, images_range, signs_range):
    '''Reads traffic sign data for German Traffic Sign Recognition Benchmark.
    Arguments: path to the traffic sign data, for example 'FullIJCNN2013'
    Returns:   list of images, list of corresponding labels'''
    images = {} # original image
    scales = {} # original scale
    for num in images_range:
        filename = rootpath + '/' + "{:05d}".format(num) + '.ppm'
        img = cv2.imread(filename, cv2.IMREAD_COLOR)
        scale = IMG_HEIGHT / float(img.shape[0])
        img_resized = cv2.resize(img, (int(img.shape[1]*scale),int(img.shape[0]*scale)))
        images.setdefault(filename,[]).append(img_resized)
        scales.setdefault(filename,[]).append(scale)

    files = [] # filenames
    signs = [] # traffic sign image
    bboxes = [] # corresponding box detection
    labels = [] # traffic sign type
    data = np.genfromtxt(rootpath + '/' + 'gt.txt', delimiter=';', dtype=str, usecols=range(0, 6))
    for elem in signs_range:
        filename = rootpath + '/' + data[elem][0]
        img = images.get(filename)[0]
        scale = scales.get(filename)[0]
        bbox = np.array([int(data[elem][1]), int(data[elem][2]), int(data[elem][3]), int(data[elem][4])]) * scale
        sign = img[int(bbox[1]):int(bbox[3]), int(bbox[0]):int(bbox[2])]
        sign_resized = cv2.resize(sign, SIGN_SIZE)
        files.append(filename)
        signs.append(sign_resized)
        bboxes.append(bbox)
        labels.append(data[elem][5])
    return images, files, signs, bboxes, labels

# %%
# The German Traffic Sign Recognition Benchmark
train_images, train_files, train_signs, train_bboxes, train_labels = readImages('FullIJCNN2013', range(0,600), range(0,852))
test_images, test_files, test_signs, test_bboxes, test_labels = readImages('FullIJCNN2013', range(600,900), range(852,1213))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

# Show examples from each class
class_names = np.unique(train_labels)
num_classes = len(class_names)
fig = plt.figure(figsize=(8,8))
for i in range(num_classes):
    ax = fig.add_subplot(6, 9, 1 + i, xticks=[], yticks=[])
    ax.set_title(class_names[i])
    indices = np.where(np.isin(train_labels, class_names[i]))[0]
    plt.imshow(cv2.cvtColor(train_signs[int(np.random.choice(indices, 1))], cv2.COLOR_BGR2RGB))
plt.show()

# %%
from sklearn.utils import shuffle
train_files, train_signs, train_bboxes, train_labels = shuffle(train_files, train_signs, train_bboxes, train_labels)
# plt.imshow(cv2.cvtColor(train_images.get(train_files[0])[0], cv2.COLOR_BGR2RGB))
# plt.show()
# plt.imshow(cv2.cvtColor(train_signs[0], cv2.COLOR_BGR2RGB))
# plt.show()
# print(train_bboxes[0])
# print(train_labels[0])

# Data pre-processing
tr_signs = np.array(train_signs)[0:600]
tr_labels = np.array(train_labels)[0:600]
va_signs = np.array(train_signs)[600:852]
va_labels = np.array(train_labels)[600:852]
te_signs = np.array(test_signs)
te_labels = np.array(test_labels)

tr_signs = tr_signs.astype('float32')
va_signs = va_signs.astype('float32')
te_signs = te_signs.astype('float32')
tr_signs /= 255.0
va_signs /= 255.0
te_signs /= 255.0

from keras.utils import np_utils
tr_labels = np_utils.to_categorical(tr_labels, num_classes)
va_labels = np_utils.to_categorical(va_labels, num_classes)
te_labels = np_utils.to_categorical(te_labels, num_classes)
# Out:
# /home/javierdlrm/environments/ffnn_environment/lib/python3.5/site-packages/sklearn/externals/joblib/_multiprocessing_helpers.py:38: UserWarning: [Errno 12] Cannot allocate memory.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))
# Using TensorFlow backend.

# %%
# Tensorboard
from time import time
from keras.callbacks import TensorBoard
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))

# %% [markdown]
# ### Assignment 1: Multi-Layer Perceptron

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras import optimizers

mlp = Sequential()
mlp.add(Dense(8, input_shape=(SIGN_SIZE[0], SIGN_SIZE[1], 3)))
mlp.add(Flatten())
mlp.add(Activation('relu'))
mlp.add(Dropout(0.2))
mlp.add(Dense(num_classes))
mlp.add(Activation('softmax'))

opt = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
mlp.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
mlp.summary()
# Out:
# WARNING:tensorflow:From /home/javierdlrm/environments/ffnn_environment/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/javierdlrm/environments/ffnn_environment/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 224, 224, 8)       32
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 401408)            0
# _________________________________________________________________
# activation_1 (Activation)    (None, 401408)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 401408)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                17260587
# _________________________________________________________________
# activation_2 (Activation)    (None, 43)                0
# =================================================================
# Total params: 17,260,619
# Trainable params: 17,260,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
data = mlp.fit(tr_signs, tr_labels, batch_size=16, epochs=100, verbose=2, validation_data=(va_signs, va_labels), callbacks=[tensorboard])

start = time()
loss, acc = mlp.evaluate(te_signs, te_labels, verbose=0)
end = time()
print('MLP took ' + str(end - start) + ' seconds')
print('Test loss: ' + str(loss) + ' - Accuracy: ' + str(acc))
# Out:
# WARNING:tensorflow:From /home/javierdlrm/environments/ffnn_environment/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 600 samples, validate on 252 samples
# Epoch 1/100
#  - 22s - loss: 4.4089 - acc: 0.1650 - val_loss: 3.3637 - val_acc: 0.1944
# Epoch 2/100
#  - 22s - loss: 2.8240 - acc: 0.2633 - val_loss: 2.4320 - val_acc: 0.3810
# Epoch 3/100
#  - 22s - loss: 2.1382 - acc: 0.4250 - val_loss: 2.1273 - val_acc: 0.4167
# Epoch 4/100
#  - 23s - loss: 1.8046 - acc: 0.5150 - val_loss: 1.8710 - val_acc: 0.5040
# Epoch 5/100
#  - 23s - loss: 1.5464 - acc: 0.5600 - val_loss: 1.8118 - val_acc: 0.5159
# Epoch 6/100
#  - 23s - loss: 1.3406 - acc: 0.6217 - val_loss: 1.6548 - val_acc: 0.5635
# Epoch 7/100
#  - 23s - loss: 1.1563 - acc: 0.6583 - val_loss: 1.8052 - val_acc: 0.4722
# Epoch 8/100
#  - 23s - loss: 1.0293 - acc: 0.6917 - val_loss: 1.6485 - val_acc: 0.5437
# Epoch 9/100
#  - 23s - loss: 0.9171 - acc: 0.7467 - val_loss: 1.5082 - val_acc: 0.5714
# Epoch 10/100
#  - 23s - loss: 0.7806 - acc: 0.7917 - val_loss: 1.8044 - val_acc: 0.5397
# Epoch 11/100
#  - 23s - loss: 0.6663 - acc: 0.8233 - val_loss: 1.5711 - val_acc: 0.5437
# Epoch 12/100
#  - 23s - loss: 0.5439 - acc: 0.8450 - val_loss: 1.5280 - val_acc: 0.5952
# Epoch 13/100
#  - 23s - loss: 0.5110 - acc: 0.8700 - val_loss: 1.4060 - val_acc: 0.6032
# Epoch 14/100
#  - 22s - loss: 0.4311 - acc: 0.8933 - val_loss: 1.6349 - val_acc: 0.5952
# Epoch 15/100
#  - 23s - loss: 0.3638 - acc: 0.9050 - val_loss: 1.4769 - val_acc: 0.6230
# Epoch 16/100
#  - 23s - loss: 0.3137 - acc: 0.9267 - val_loss: 1.4947 - val_acc: 0.6349
# Epoch 17/100
#  - 22s - loss: 0.2499 - acc: 0.9483 - val_loss: 1.6596 - val_acc: 0.5873
# Epoch 18/100
#  - 23s - loss: 0.2671 - acc: 0.9317 - val_loss: 1.5225 - val_acc: 0.6389
# Epoch 19/100
#  - 23s - loss: 0.3167 - acc: 0.9233 - val_loss: 1.4989 - val_acc: 0.6429
# Epoch 20/100
#  - 23s - loss: 0.2096 - acc: 0.9650 - val_loss: 1.4150 - val_acc: 0.6230
# Epoch 21/100
#  - 23s - loss: 0.2586 - acc: 0.9500 - val_loss: 1.5703 - val_acc: 0.6151
# Epoch 22/100
#  - 23s - loss: 0.2274 - acc: 0.9567 - val_loss: 1.3958 - val_acc: 0.6349
# Epoch 23/100
#  - 23s - loss: 0.2219 - acc: 0.9567 - val_loss: 1.3689 - val_acc: 0.6429
# Epoch 24/100
#  - 23s - loss: 0.1351 - acc: 0.9833 - val_loss: 1.4076 - val_acc: 0.6548
# Epoch 25/100
#  - 23s - loss: 0.1143 - acc: 0.9817 - val_loss: 1.3789 - val_acc: 0.6706
# Epoch 26/100
#  - 23s - loss: 0.1322 - acc: 0.9750 - val_loss: 1.4118 - val_acc: 0.6349
# Epoch 27/100
#  - 23s - loss: 0.1074 - acc: 0.9867 - val_loss: 1.5030 - val_acc: 0.6548
# Epoch 28/100
#  - 23s - loss: 0.0925 - acc: 0.9817 - val_loss: 1.3209 - val_acc: 0.6944
# Epoch 29/100
#  - 23s - loss: 0.0812 - acc: 0.9917 - val_loss: 1.3515 - val_acc: 0.6865
# Epoch 30/100
#  - 23s - loss: 0.0800 - acc: 0.9917 - val_loss: 1.3741 - val_acc: 0.6706
# Epoch 31/100
#  - 23s - loss: 0.0709 - acc: 0.9850 - val_loss: 1.3660 - val_acc: 0.6746
# Epoch 32/100
#  - 23s - loss: 0.0564 - acc: 0.9933 - val_loss: 1.4070 - val_acc: 0.6786
# Epoch 33/100
#  - 23s - loss: 0.0554 - acc: 0.9950 - val_loss: 1.4164 - val_acc: 0.6905
# Epoch 34/100
#  - 23s - loss: 0.0454 - acc: 0.9983 - val_loss: 1.3990 - val_acc: 0.6905
# Epoch 35/100
#  - 23s - loss: 0.0498 - acc: 0.9933 - val_loss: 1.4092 - val_acc: 0.6944
# Epoch 36/100
#  - 23s - loss: 0.0493 - acc: 0.9983 - val_loss: 1.4810 - val_acc: 0.6746
# Epoch 37/100
#  - 23s - loss: 0.0391 - acc: 0.9983 - val_loss: 1.4568 - val_acc: 0.6905
# Epoch 38/100
#  - 23s - loss: 0.0422 - acc: 0.9950 - val_loss: 1.3923 - val_acc: 0.7063
# Epoch 39/100
#  - 23s - loss: 0.0340 - acc: 0.9983 - val_loss: 1.4333 - val_acc: 0.7024
# Epoch 40/100
#  - 23s - loss: 0.0375 - acc: 0.9950 - val_loss: 1.4744 - val_acc: 0.6905
# Epoch 41/100
#  - 23s - loss: 0.0304 - acc: 0.9983 - val_loss: 1.3957 - val_acc: 0.6944
# Epoch 42/100
#  - 23s - loss: 0.0294 - acc: 0.9983 - val_loss: 1.3972 - val_acc: 0.7024
# Epoch 43/100
#  - 23s - loss: 0.0309 - acc: 0.9967 - val_loss: 1.3900 - val_acc: 0.7143
# Epoch 44/100
#  - 23s - loss: 0.0376 - acc: 0.9917 - val_loss: 1.3538 - val_acc: 0.7222
# Epoch 45/100
#  - 23s - loss: 0.0277 - acc: 0.9967 - val_loss: 1.4512 - val_acc: 0.6944
# Epoch 46/100
#  - 23s - loss: 0.0260 - acc: 0.9983 - val_loss: 1.3869 - val_acc: 0.7103
# Epoch 47/100
#  - 23s - loss: 0.0229 - acc: 0.9967 - val_loss: 1.3873 - val_acc: 0.7063
# Epoch 48/100
#  - 23s - loss: 0.0239 - acc: 0.9983 - val_loss: 1.4730 - val_acc: 0.7063
# Epoch 49/100
#  - 23s - loss: 0.0200 - acc: 1.0000 - val_loss: 1.3699 - val_acc: 0.7183
# Epoch 50/100
#  - 23s - loss: 0.0178 - acc: 1.0000 - val_loss: 1.4207 - val_acc: 0.7103
# Epoch 51/100
#  - 23s - loss: 0.0279 - acc: 0.9950 - val_loss: 1.5405 - val_acc: 0.6944
# Epoch 52/100
#  - 22s - loss: 0.0271 - acc: 0.9950 - val_loss: 1.4006 - val_acc: 0.7262
# Epoch 53/100
#  - 23s - loss: 0.0222 - acc: 0.9983 - val_loss: 1.4088 - val_acc: 0.6984
# Epoch 54/100
#  - 22s - loss: 0.0169 - acc: 1.0000 - val_loss: 1.4121 - val_acc: 0.7222
# Epoch 55/100
#  - 22s - loss: 0.0150 - acc: 1.0000 - val_loss: 1.4451 - val_acc: 0.7024
# Epoch 56/100
#  - 23s - loss: 0.0172 - acc: 0.9983 - val_loss: 1.4541 - val_acc: 0.7143
# Epoch 57/100
#  - 22s - loss: 0.0147 - acc: 1.0000 - val_loss: 1.4223 - val_acc: 0.7222
# Epoch 58/100
#  - 23s - loss: 0.0140 - acc: 1.0000 - val_loss: 1.4344 - val_acc: 0.7183
# Epoch 59/100
#  - 22s - loss: 0.0127 - acc: 1.0000 - val_loss: 1.4038 - val_acc: 0.7262
# Epoch 60/100
#  - 23s - loss: 0.0130 - acc: 1.0000 - val_loss: 1.4416 - val_acc: 0.7103
# Epoch 61/100
#  - 23s - loss: 0.0132 - acc: 1.0000 - val_loss: 1.4545 - val_acc: 0.7103
# Epoch 62/100
#  - 23s - loss: 0.0117 - acc: 1.0000 - val_loss: 1.4242 - val_acc: 0.7103
# Epoch 63/100
#  - 23s - loss: 0.0114 - acc: 1.0000 - val_loss: 1.4325 - val_acc: 0.7103
# Epoch 64/100
#  - 23s - loss: 0.0107 - acc: 1.0000 - val_loss: 1.4342 - val_acc: 0.7183
# Epoch 65/100
#  - 23s - loss: 0.0099 - acc: 1.0000 - val_loss: 1.4448 - val_acc: 0.7183
# Epoch 66/100
#  - 23s - loss: 0.0097 - acc: 1.0000 - val_loss: 1.4612 - val_acc: 0.7183
# Epoch 67/100
#  - 23s - loss: 0.0103 - acc: 1.0000 - val_loss: 1.4363 - val_acc: 0.7183
# Epoch 68/100
#  - 22s - loss: 0.0110 - acc: 1.0000 - val_loss: 1.4673 - val_acc: 0.7262
# Epoch 69/100
#  - 22s - loss: 0.0093 - acc: 1.0000 - val_loss: 1.4454 - val_acc: 0.7143
# Epoch 70/100
#  - 23s - loss: 0.0097 - acc: 1.0000 - val_loss: 1.4824 - val_acc: 0.7183
# Epoch 71/100
#  - 23s - loss: 0.0094 - acc: 1.0000 - val_loss: 1.4474 - val_acc: 0.7183
# Epoch 72/100
#  - 23s - loss: 0.0085 - acc: 1.0000 - val_loss: 1.4530 - val_acc: 0.7183
# Epoch 73/100
#  - 23s - loss: 0.0075 - acc: 1.0000 - val_loss: 1.4969 - val_acc: 0.7183
# Epoch 74/100
#  - 22s - loss: 0.0082 - acc: 1.0000 - val_loss: 1.4510 - val_acc: 0.7302
# Epoch 75/100
#  - 23s - loss: 0.0082 - acc: 1.0000 - val_loss: 1.4381 - val_acc: 0.7262
# Epoch 76/100
#  - 23s - loss: 0.0079 - acc: 1.0000 - val_loss: 1.4840 - val_acc: 0.7302
# Epoch 77/100
#  - 23s - loss: 0.0080 - acc: 1.0000 - val_loss: 1.4752 - val_acc: 0.7262
# Epoch 78/100
#  - 23s - loss: 0.0076 - acc: 1.0000 - val_loss: 1.4565 - val_acc: 0.7341
# Epoch 79/100
#  - 22s - loss: 0.0071 - acc: 1.0000 - val_loss: 1.4724 - val_acc: 0.7262
# Epoch 80/100
#  - 23s - loss: 0.0071 - acc: 1.0000 - val_loss: 1.4906 - val_acc: 0.7341
# Epoch 81/100
#  - 23s - loss: 0.0073 - acc: 1.0000 - val_loss: 1.4993 - val_acc: 0.7262
# Epoch 82/100
#  - 23s - loss: 0.0076 - acc: 1.0000 - val_loss: 1.4813 - val_acc: 0.7381
# Epoch 83/100
#  - 23s - loss: 0.0074 - acc: 1.0000 - val_loss: 1.4877 - val_acc: 0.7302
# Epoch 84/100
#  - 23s - loss: 0.0070 - acc: 1.0000 - val_loss: 1.4937 - val_acc: 0.7302
# Epoch 85/100
#  - 22s - loss: 0.0071 - acc: 1.0000 - val_loss: 1.4907 - val_acc: 0.7262
# Epoch 86/100
#  - 22s - loss: 0.0061 - acc: 1.0000 - val_loss: 1.4824 - val_acc: 0.7341
# Epoch 87/100
#  - 23s - loss: 0.0059 - acc: 1.0000 - val_loss: 1.4597 - val_acc: 0.7262
# Epoch 88/100
#  - 23s - loss: 0.0059 - acc: 1.0000 - val_loss: 1.5035 - val_acc: 0.7341
# Epoch 89/100
#  - 23s - loss: 0.0060 - acc: 1.0000 - val_loss: 1.5642 - val_acc: 0.7143
# Epoch 90/100
#  - 23s - loss: 0.0060 - acc: 1.0000 - val_loss: 1.5073 - val_acc: 0.7262
# Epoch 91/100
#  - 23s - loss: 0.0060 - acc: 1.0000 - val_loss: 1.5023 - val_acc: 0.7262
# Epoch 92/100
#  - 23s - loss: 0.0060 - acc: 1.0000 - val_loss: 1.4996 - val_acc: 0.7421
# Epoch 93/100
#  - 23s - loss: 0.0058 - acc: 1.0000 - val_loss: 1.4857 - val_acc: 0.7341
# Epoch 94/100
#  - 22s - loss: 0.0057 - acc: 1.0000 - val_loss: 1.4946 - val_acc: 0.7421
# Epoch 95/100
#  - 22s - loss: 0.0054 - acc: 1.0000 - val_loss: 1.4832 - val_acc: 0.7302
# Epoch 96/100
#  - 22s - loss: 0.0056 - acc: 1.0000 - val_loss: 1.4902 - val_acc: 0.7381
# Epoch 97/100
#  - 22s - loss: 0.0053 - acc: 1.0000 - val_loss: 1.5010 - val_acc: 0.7341
# Epoch 98/100
#  - 22s - loss: 0.0052 - acc: 1.0000 - val_loss: 1.5007 - val_acc: 0.7341
# Epoch 99/100
#  - 23s - loss: 0.0049 - acc: 1.0000 - val_loss: 1.5002 - val_acc: 0.7381
# Epoch 100/100
#  - 23s - loss: 0.0048 - acc: 1.0000 - val_loss: 1.5053 - val_acc: 0.7302
# MLP took 1.6747870445251465 seconds
# Test loss: 0.8484582126635924 - Accuracy: 0.822714681605553
